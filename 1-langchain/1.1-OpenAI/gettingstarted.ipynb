# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")  # call API key from openai
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY") # call API key from Langchain 
# for Langsmith tracking
os.environ["LANGCHAIN_TRACING_V2"] = "true" 
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-o4")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001A03CEF9090> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001A03CEF8400> root_client=<openai.OpenAI object at 0x000001A03CE7F4F0> root_async_client=<openai.AsyncOpenAI object at 0x000001A03CEF8EB0> model_name='gpt-o4' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get responce from the LLM

result = llm.invoke("How llm works?")
print(result)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 3
#       1 ## Input and get responce from the LLM
# ----> 3 result = llm.invoke("How llm works?")
#       4 print(result)
#
# File e:\folder E\Udemy\langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)
#     363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
# ...

# %% [markdown]
#     Because i have a free account in OPEN AI so getting the error as we can't access the Model
#
#     But we can see the run was traked in langsmit wed

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Chart Prompt Template

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system","you are an export AI enginner.provide me answers based on the question"),
        ("user","{input}")
        
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an export AI enginner.provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# compibine prompt template and the llm

chain = prompt|llm
response = chain.invoke({"input":"what is langsmith?"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[10], line 4
#       1 # compibine prompt template and the llm
#       3 chain = prompt|llm
# ----> 4 response = chain.invoke({"input":"what is langsmith?"})
#       5 print(response)
#
# File e:\folder E\Udemy\langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3034, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3032                 input = context.run(step.invoke, input, config, **kwargs)
#    3033             else:
# -> 3034                 input = context.run(step.invoke, input, config)
#    3035 # finish the root run
#    3036 except BaseException as e:
#
# File e:\folder E\Udemy\langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
# ...

# %% [markdown]
#     Because i have a free account in OPEN AI so getting the error as we can't access the Model

# %%
type(response)  # type is AImessage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 type(response)  # type is AImessage
#
# NameError: name 'response' is not defined

# %% [markdown]
#     Because i have a free account in OPEN AI so getting the error as we can't access the Model so response as a variable is not created

# %%
# str output parser

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"what is langsmith?"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 7
#       4 output_parser = StrOutputParser()
#       5 chain = prompt|llm|output_parser
# ----> 7 response = chain.invoke({"input":"what is langsmith?"})
#       8 print(response)
#
# File e:\folder E\Udemy\langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3034, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3032                 input = context.run(step.invoke, input, config, **kwargs)
#    3033             else:
# -> 3034                 input = context.run(step.invoke, input, config)
#    3035 # finish the root run
#    3036 except BaseException as e:
#
# File e:\folder E\Udemy\langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
# ...

# %% [markdown]
#     Because i have a free account in OPEN AI so getting the error as we can't access the Model

# %% [markdown]
# ------------------------------------------------------
